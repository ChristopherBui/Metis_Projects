# %%
from keras.models import Model, load_model
import numpy as np
import matplotlib.pyplot as plt
from skimage.io import imread, imshow
from model import *
import pickle
# Out:
# /anaconda/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
y_pred = pickle.load(open('x_pred.pickle','rb'))

# %%
y_true = pickle.load(open('y_val.pickle','rb'))

# %%
y_pred.shape
# Out:
# (70, 128, 128, 1)

# %%
y_true.shape
# Out:
# (70, 128, 128, 1)

# %%
img1 = y_pred[0]
img2 = y_true[0]

# %%
print(img1.shape,'\n',img2.shape)
# Out:
# (128, 128, 1)
#  (128, 128, 1)

# %%
imshow(np.squeeze(img1),cmap='gray')

# %%
plt.show()

# %%
imshow(np.squeeze(img2))

# %%
plt.show()

# %%
imshow(np.squeeze(y_pred[60]),cmap='gray')
plt.show()

# %%
imshow(np.squeeze(y_true[60]),cmap='gray')
plt.show()

# %%
imga = imread('y.png')
print(imga.shape)
imshow(imga)
plt.show()
# Out:
# (960, 1280, 4)

# %%
imgb = imread('z.png')
print(imgb.shape)
imshow(imgb)
plt.show()
# Out:
# (960, 1280, 4)

# %%
black = np.zeros((960,1280,4))

# %%
black.shape
# Out:
# (960, 1280, 4)

# %%
overlap = np.array([[imga],[imgb],[black]])

# %%
imshow(np.squeeze(y_pred[69]),cmap='gray')
plt.show()
imshow(np.squeeze(y_true[69]))
plt.show()

# %%
type(img2)
# Out:
# numpy.ndarray

# %%
img2.shape
# Out:
# (128, 128, 1)

# %%
img3 = np.zeros([128,128,3])

# %%
img3[:,:,0] = img2[:,:,0]
img3[:,:,1] = img2[:,:,0]

# %%
plt.imshow(img3)
plt.show()

# %%
def iou(img1, img2):
    intersection = np.sum(img1 * img2)
    union = np.sum(img1+img2) - intersection

    #if not union:
        #return 1

    return intersection / union
